# %% [markdown]
# <a href="https://colab.research.google.com/github/Anaju7/Aulas_Python/blob/main/Aula_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 11

# %% [markdown]
# **Leitura e escrita de arquivos  CSV**
#
# Introdução aos arquivos CSV

# %%
import pandas as pd

# %% [markdown]
# Leitura de arquivos

# %%
df = pd.read_csv('exemplo_profissao.csv')

# %%
df
# Out:
#       Nome  Idade   Profissão
# 0    Alice     24  Engenheira
# 1      Bob     27      Médico
# 2  Charlie     22   Professor
# 3    David     32    Designer
# 4      Eva     29    Advogada

# %%
print(df)
# Out:
#       Nome  Idade   Profissão
# 0    Alice     24  Engenheira
# 1      Bob     27      Médico
# 2  Charlie     22   Professor
# 3    David     32    Designer
# 4      Eva     29    Advogada

# %% [markdown]
# ### Exercicios

# %% [markdown]
# Agora que você aprendeu os conceitos básicos, é hora de praticar. Tente as seguintes tarefas:
#
# Leia um arquivo CSV de sua escolha e visualize os primeiros cinco registros.
#
# Crie um novo DataFrame com dados de sua escolha e salve-o como um arquivo CSV.
#
# Explore diferentes parâmetros da função **pd.read_csv()** e **pd.DataFrame.to_csv()**, como **delimiter** e **header**.

# %%
arq_df = pd.read_csv('california_housing_test.csv')
arq_df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
ar_df02 = pd.DataFrame({
    'Nome': ['João', 'Maria', 'Pedro'],
    'Idade': [25, 30, 35],
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte']
})
ar_df02.to_csv('novo_arquivo.csv', index=False)
ar_df02.head()
# Out:
#     Nome  Idade          Cidade
# 0   João     25       São Paulo
# 1  Maria     30  Rio de Janeiro
# 2  Pedro     35  Belo Horizonte

# %%
novo_df = pd.read_csv('novo_arquivo.csv', delimiter='-')
print(novo_df)
# Out:
#          Nome,Idade,Cidade
# 0        João,25,São Paulo
# 1  Maria,30,Rio de Janeiro
# 2  Pedro,35,Belo Horizonte

# %% [markdown]
# ### APIS

# %%
import requests
import json

response = requests.get('https://jsonplaceholder.typicode.com/posts')

JsonResponse = response.json()

print(json.dumps(JsonResponse[1], indent=4))
# Out:
# {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
# }

# %%
import pandas as pd
df = pd.DataFrame(JsonResponse)
df.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# Detalhando respostas

# %%
print(list(JsonResponse[0]))
# Out:
# ['userId', 'id', 'title', 'body']

# %% [markdown]
# #### Tratamento de Erros

# %%
try:
 response = requests.get('https://jsonplaceholder.typicode.com/posts')
 response.raise_for_status()
 data = response.json()
except requests.exceptions.HTTPError as erro:
 print(f'Erro HTTP: {erro}')
except requests.exceptions.ConnectionError as erro:
  print(f'Erro de conexão: {erro}')
except requests.exceptions.Timeout as erro:
  print(f'Erro de timeout: {erro}')
except requests.exceptions.RequestException as erro:
  print(f'Erro de requisição: {erro}')

# %% [markdown]
# ##Exercicios

# %% [markdown]
# Agora que você aprendeu como consumir e processar dados de uma API em Python, tente os seguintes exercícios:
#
# Encontre uma API pública de sua escolha e faça uma requisição para obter dados.
#
# Analise a estrutura dos dados retornados e extraia informações úteis.
#
# Faça diversas requisições para diferentes endpoints da API e explore os dados retornados.

# %%
ResponseCharacter = requests.get('https://rickandmortyapi.com/api/character')
ResponseLocations = requests.get('https://rickandmortyapi.com/api/location')

jsonResponseLocations = ResponseLocations.json()
JsonResponseCharacter = ResponseCharacter.json()

location = jsonResponseLocations['results']
personagem = JsonResponseRickandMorty['results'][0]

locPlan = ""
for i in location:
  if i['name'] == personagem['origin']['name']:
    locPlan = i['name']


print(f"personagem: {personagem['name']}, especie: {personagem['species']}, status: {personagem['status']}, planeta: {locPlan}")
# Out:
# personagem: Rick Sanchez, especie: Human, status: Alive, planeta: Earth (C-137)
